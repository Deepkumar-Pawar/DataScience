# %%
#@title Import Libraries
import numpy as np
import json
import re
import tensorflow as tf
import pandas as pd
import io
import math
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 1500)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
#@title Upload Log Files
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c1461286-a88e-4230-aa30-edca88b8bc31" name="files[]" multiple disabled />
#      <output id="result-c1461286-a88e-4230-aa30-edca88b8bc31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Good.log to Good.log
# Saving node124.log to node124.log
# Saving node125.log to node125.log

# %%
#@title Mount Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
#@title Preprocess Raw Log Data
#Preprocess the raw log file data

def pre_process_features(logs):
  time_from_start = {}    #Time elapsed since node was booted
  time_in_ms = {}         #Time in milliseconds
  text = {}               #Actual Log text
  text_code = {}          #Log text encoded in numeric form
  
  i = 0
  
  last_was_tx = False
  last_was_rx = False
  
  exp = re.compile(r"\:")
  exp_match_hdlc = re.compile(r"hdlc")
  
  #In the following code we are extracting the relevant parts of the log file data and storing them in a pandas series
  
  for line in logs:
    
    m = exp_match_hdlc.search(line[72 : 90])
    
    #We then encode the log text in a numeric format
    
    if m:
      
      time_from_start[i] = line[52 : 63]
      time_in_ms[i] = (int(time_from_start[i][8 :]) * 1) + (int(time_from_start[i][5 : 7]) * 1000) + (int(time_from_start[i][2 : 4]) * 60000) + (int(time_from_start[i][: 1]) * 3600000)
      
      text[i] = (exp.split(line[63:], maxsplit = 1)[-1]).strip()#[:-1]
      
      if (text[i] == "** Waiting for HDLC event (60000ms) **"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 0
        
      elif(text[i] == "disconnectLink 0x0"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 1
        
      elif(text[i] == "-- HDLC locked --"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 2
        
      elif (text[i] == "Connect HDLC link"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 3
        
      elif (text[i][: 2] == "tx"):
        if (last_was_tx):
          i = i - 1
        
        text_code[i] = 4
        text[i] = "[tx block]"
        last_was_tx = True
        
      elif (text[i][: 2] == "rx"):
        if (last_was_rx):
          i = i - 1
        
        text_code[i] = 5
        text[i] = "[rx block]"
        last_was_rx = True
        
      elif (text[i] == "ACTION_WAIT_FOR_RESPONSE"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 6
        
      elif (text[i] == "HDLC_TYPE_UA"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 7
        
      elif (text[i] == "!! Result == ResultOK !!"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 8
        
      elif (text[i] == "Passing IFrame up the stack to the DLMS task."):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 9
        
      elif (text[i] == "-- unlocking HDLC --"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 10
        
      elif (text[i] == "Disconnect HDLC link"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 11
            
      elif (text[i] == "HDLC_TYPE_I"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 12
        
      else: #text is anything other than the above
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 13
      
      text_code[i] = text_code[i] * 1
      
      i = i + 1
  
  return pd.Series(time_from_start), pd.Series(time_in_ms), pd.Series(text), pd.Series(text_code)

# %%
def pre_process_features(logs):   #Preprocess the entire log file
  time_from_start = {}    #Time elapsed since node was booted
  time_in_ms = {}         #Time in milliseconds
  text = {}               #Actual Log text
  text_code = {}          #Log text encoded in numeric form
  line_numbers = {}
  
  i = 0
  
  line_number = 0
  
  last_was_tx = False
  last_was_rx = False
  
  exp = re.compile(r"\:")
  exp_match_hdlc = re.compile(r"hdlc")
  
  #In the following code we are extracting the relevant parts of the log file data and storing them in a pandas series
  
  for line in logs:
    
    line_number = line_number + 1
    
    m = exp_match_hdlc.search(line[72 : 90])
    
    #We then encode the log text in a numeric format
    
    if m:
      
      line_numbers[i] = line_number
      
      time_from_start[i] = line[52 : 63]
      time_in_ms[i] = (int(time_from_start[i][8 :]) * 1) + (int(time_from_start[i][5 : 7]) * 1000) + (int(time_from_start[i][2 : 4]) * 60000) + (int(time_from_start[i][: 1]) * 3600000)
      
      text[i] = (exp.split(line[63:], maxsplit = 1)[-1]).strip()#[:-1]
      
      if (text[i] == "** Waiting for HDLC event (60000ms) **"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 0
        
      elif(text[i] == "disconnectLink 0x0"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 1
        
      elif(text[i] == "-- HDLC locked --"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 2
        
      elif (text[i] == "Connect HDLC link"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 3
        
      elif (text[i][: 2] == "tx"):
        if (last_was_tx):
          i = i - 1
        
        text_code[i] = 4
        text[i] = "[tx block]"
        last_was_tx = True
        
      elif (text[i][: 2] == "rx"):
        if (last_was_rx):
          i = i - 1
        
        text_code[i] = 5
        text[i] = "[rx block]"
        last_was_rx = True
        
      elif (text[i] == "ACTION_WAIT_FOR_RESPONSE"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 6
        
      elif (text[i] == "HDLC_TYPE_UA"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 7
        
      elif (text[i] == "!! Result == ResultOK !!"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 8
        
      elif (text[i] == "Passing IFrame up the stack to the DLMS task."):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 9
        
      elif (text[i] == "-- unlocking HDLC --"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 10
        
      elif (text[i] == "Disconnect HDLC link"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 11
            
      elif (text[i] == "HDLC_TYPE_I"):
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 12
        
      else: #text is anything other than the above
        last_was_tx = False
        last_was_rx = False
        text_code[i] = 13
      
      text_code[i] = text_code[i] * 1
      
      i = i + 1
  
  return pd.Series(line_numbers), pd.Series(time_from_start), pd.Series(time_in_ms), pd.Series(text), pd.Series(text_code)

def create_batches(df, windows, input, output):
  ## Create X         
  x_data = df[:size_train-1] # Select the data
  if((x_data.size % windows != 0)):
     x_data = x_data[: x_data.size - (x_data.size % windows)]
  X_batches = x_data.reshape(-1, windows, input)  # Reshape the data 
  ## Create y
  y_data = df[n_output:size_train]
  if((y_data.size % windows != 0)):
     y_data = y_data[: y_data.size - (y_data.size % windows)]
  y_batches = y_data.reshape(-1, windows, output)
  
  return X_batches, y_batches

def create_series_array_dict(arr):
  
  d = {}
  
  arr = arr[:arr.size - arr.size % (test_windows + 1)]
  
  for i in range(0, arr.size - (test_windows + 1)):
    d[i] = arr[i : (i + (test_windows + 1))]
  
  return d

def create_test_batches (d):
  d_x = {}
  d_y = {}
  
  for i in range(len(d)):
    d_x[i], d_y[i] = create_batches(df = d[i], windows = test_windows,input = 1, output = 1)
  
  return d_x, d_y

def log_alert(line_number):
  print("\nPassed threshold at around line", line_number)
  return

# %%
#@title Save the preprocessed data in a Pandas DataFrame
#This part is saving the preprocessed log data into pandas dataframes

path1='node124.log'
path2='node125.log'
path_good = 'Good.log'

log_data1=open(path1,'r')
log_data2=open(path2,'r')
log_data_good = open(path_good, 'r')

line_numbers, time_from_start, time_in_ms, text, text_code = pre_process_features(log_data1)

df1 = pd.DataFrame({'line_numbers': line_numbers, 'time_from_start': time_from_start, 'time_in_ms': time_in_ms, 'text': text, 'text_code': text_code})

line_numbers, time_from_start, time_in_ms, text, text_code = pre_process_features(log_data2)

df2 = pd.DataFrame({'line_numbers': line_numbers, 'time_from_start': time_from_start, 'time_in_ms': time_in_ms, 'text': text, 'text_code': text_code})

line_numbers, time_from_start, time_in_ms, text, text_code = pre_process_features(log_data_good)

df_good = pd.DataFrame({'line_numbers': line_numbers, 'time_from_start': time_from_start, 'time_in_ms': time_in_ms, 'text': text, 'text_code': text_code})

# %%
path_good = 'Good.log'
log_data_good = open(path_good, 'r')

line_numbers, time_from_start, time_in_ms, text, text_code = pre_process_features(log_data_good)
df_good = pd.DataFrame({'line_numbers': line_numbers, 'time_from_start': time_from_start, 'time_in_ms': time_in_ms, 'text': text, 'text_code': text_code})

series = np.array(df_good["text_code"])   #Convert the data to a numpy array

n_windows = 20       #number of data elements in a batch
n_input =  1         #for reshaping the data
n_output = 1         #for reshaping the data
size_train = int(len(series) * 4 / 5)

## Split data
train = series[:size_train]
test = series[size_train:]

#To reshape the data into batches

X_batches, y_batches = create_batches(df = train,
                                      windows = n_windows,
                                      input = n_input,
                                      output = n_output)

X_test, y_test = create_batches(df = test, windows = n_windows, input = n_input, output = n_output)

tf.reset_default_graph()    #Reset to the initial graph

r_neuron = 240              #The number of neurons
#num_layers = 10            #The number of hidden layers

#Construct the tensors
X = tf.placeholder(tf.float32, [None, n_windows, n_input])
y = tf.placeholder(tf.float32, [None, n_windows, n_output])
                                                               #These are placeholders which are simply variables to hold values

#Create the model

cell = tf.keras.layers.SimpleRNNCell(units=r_neuron, activation=tf.nn.relu) 
#cell = tf.nn.rnn_cell.LSTMCell(num_units = r_neuron, activation = tf.nn.relu)

#Creating the RNN LSTM cell itself

#cells = tf.keras.layers.StackedRNNCells(cell for _ in range(num_layers))      #Create a multi LSTM RNN

rnn_output, states = tf.nn.dynamic_rnn(cell, X, dtype=tf.float32)

#Creates the RNN and returns an output

stacked_rnn_output = tf.reshape(rnn_output, [-1, r_neuron])         #Flattens the tensor to 1D
stacked_outputs = tf.layers.dense(stacked_rnn_output, n_output)
outputs = tf.reshape(stacked_outputs, [-1, n_windows, n_output])   

#Applying transformations to the output received into a usable form

## 3. Loss + optimization
learning_rate = 0.002     #The learning rate
 
#loss = tf.reduce_sum(tf.square(outputs - y)) 
loss = tf.losses.mean_squared_error(y, outputs)      #To calculate Loss on the training set
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)       #The optimizer used  
training_op = optimizer.minimize(loss)             #Create the Training operation

round_op = tf.round(y)    #To round values off
clip_op = tf.clip_by_value(t = y, clip_value_min = 0, clip_value_max = 13)     #To clip values off
loss_test = tf.losses.mean_squared_error(tf.round(y), tf.round(X))     #To calculate Loss on the test set

init = tf.global_variables_initializer()    #To Initialize and reset the model

saver = tf.train.Saver()    #To save the model
# Out:
# WARNING:tensorflow:From <ipython-input-8-8d42118c64d0>:46: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From <ipython-input-8-8d42118c64d0>:51: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
#@title Initialize Model and Weights
with tf.Session() as sess:
  init.run()
  save_path = saver.save(sess, "/tmp/model.ckpt")

# %%
#@title Train Existing Saved Model
epochs = 7500 #@param {type:"integer"}

with tf.Session() as sess:
  saver.restore(sess, "/tmp/model.ckpt")
  
  for epoch in range(epochs):
    sess.run(training_op, feed_dict={X: X_batches, y: y_batches})
    if epoch % 150 == 0:
      mse = loss.eval(feed_dict={X: X_batches, y: y_batches})
      print(epoch, "\tMSE:", mse)
  
  save_path = saver.save(sess, "/tmp/model.ckpt")
  
  y_pred = sess.run(outputs, feed_dict={X: X_test})
  y_pred = sess.run(round_op, feed_dict={y: y_pred})
  y_pred = sess.run(clip_op, feed_dict={y: y_pred})
  test_mse = loss_test.eval(feed_dict={X: y_pred, y: y_test})
  print("Test MSE:", test_mse)
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/model.ckpt
# 0 	MSE: 1.4040793
# 150 	MSE: 1.3731235
# 300 	MSE: 1.372521
# 450 	MSE: 1.3112212
# 600 	MSE: 1.2905693
# 750 	MSE: 1.2699399
# 900 	MSE: 1.2449094
# 1050 	MSE: 1.3117474
# 1200 	MSE: 1.2106551
# 1350 	MSE: 1.1941807
# 1500 	MSE: 1.1833115
# 1650 	MSE: 1.1672306
# 1800 	MSE: 1.1559066
# 1950 	MSE: 1.1442839
# 2100 	MSE: 1.1382657
# 2250 	MSE: 1.1324183
# 2400 	MSE: 1.1125761
# 2550 	MSE: 1.103614
# 2700 	MSE: 1.1221315
# 2850 	MSE: 1.0979841
# 3000 	MSE: 1.076002
# 3150 	MSE: 1.0723139
# 3300 	MSE: 1.0661075
# 3450 	MSE: 1.0509571
# 3600 	MSE: 1.0444288
# 3750 	MSE: 1.037027
# 3900 	MSE: 1.0332007
# 4050 	MSE: 1.0357717
# 4200 	MSE: 1.0535682
# 4350 	MSE: 1.0279149
# 4500 	MSE: 1.0197554
# 4650 	MSE: 1.0158005
# 4800 	MSE: 1.0045161
# 4950 	MSE: 1.0018698
# 5100 	MSE: 0.99926555
# 5250 	MSE: 1.0497575
# 5400 	MSE: 0.9977267
# 5550 	MSE: 0.9961215
# 5700 	MSE: 0.9953775
# 5850 	MSE: 0.9913754
# 6000 	MSE: 0.9876031
# 6150 	MSE: 0.9810082
# 6300 	MSE: 0.99627316
# 6450 	MSE: 0.97546136
# 6600 	MSE: 0.9751365
# 6750 	MSE: 1.0168545
# 6900 	MSE: 0.9768923
# 7050 	MSE: 0.9731101
# 7200 	MSE: 0.9712624
# 7350 	MSE: 0.9756214
# Test MSE: 1.9752631

# %% [markdown]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
path='node125.log'
log_data=open(path,'r')

line_numbers, time_from_start, time_in_ms, text, text_code = pre_process_features(log_data)
df = pd.DataFrame({'line_numbers': line_numbers, 'time_from_start': time_from_start, 'time_in_ms': time_in_ms, 'text': text, 'text_code': text_code})

test_series = np.array(df["text_code"])

test_windows = 20

series_array_dict = create_series_array_dict(test_series)

n = len(series_array_dict)

test_batch_dict_x, test_batch_dict_y = create_test_batches(series_array_dict)

threshold = 25

with tf.Session() as sess:
  saver.restore(sess, "/tmp/model.ckpt")
  
  logs_stabilized = True
  
  last_passed_threshold_line = 0
  
  y_test_predictions_dict = {}
  
  for i in range(n):
    
    line_number = i + (test_windows + 1)
    
    y_test_predictions_dict[i] = sess.run(outputs, feed_dict={X: test_batch_dict_x[i]})
    y_test_predictions_dict[i] = sess.run(round_op, feed_dict={y: y_test_predictions_dict[i]})
    test_mse = loss_test.eval(feed_dict={X: y_test_predictions_dict[i], y: test_batch_dict_y[i]})
    
    if(test_mse < 10):
      logs_stabilized = True
    
    print("MSE:", test_mse, "\t\tat line\t", df["line_numbers"][i], "\tof the entire log file and at line\t", line_number, "\tof the HDLC logs")
    
    if ((test_mse > threshold) & (logs_stabilized)):
      logs_stabilized = False
      log_alert(df["line_numbers"][i])
# Out:
# MSE: 1.0 		at line	 236 	of the entire log file and at line	 21 	of the HDLC logs
# MSE: 3.9 		at line	 239 	of the entire log file and at line	 22 	of the HDLC logs
# MSE: 0.9 		at line	 288 	of the entire log file and at line	 23 	of the HDLC logs
# MSE: 0.25 		at line	 289 	of the entire log file and at line	 24 	of the HDLC logs
# MSE: 0.75 		at line	 291 	of the entire log file and at line	 25 	of the HDLC logs
# MSE: 1.05 		at line	 292 	of the entire log file and at line	 26 	of the HDLC logs
# MSE: 1.0 		at line	 303 	of the entire log file and at line	 27 	of the HDLC logs
# MSE: 0.85 		at line	 304 	of the entire log file and at line	 28 	of the HDLC logs
# MSE: 0.05 		at line	 306 	of the entire log file and at line	 29 	of the HDLC logs
# MSE: 1.75 		at line	 307 	of the entire log file and at line	 30 	of the HDLC logs
# MSE: 1.5 		at line	 318 	of the entire log file and at line	 31 	of the HDLC logs
# MSE: 2.1 		at line	 319 	of the entire log file and at line	 32 	of the HDLC logs
# MSE: 2.65 		at line	 320 	of the entire log file and at line	 33 	of the HDLC logs
# MSE: 4.1 		at line	 321 	of the entire log file and at line	 34 	of the HDLC logs
# MSE: 3.25 		at line	 325 	of the entire log file and at line	 35 	of the HDLC logs
# MSE: 3.65 		at line	 326 	of the entire log file and at line	 36 	of the HDLC logs
# MSE: 4.85 		at line	 327 	of the entire log file and at line	 37 	of the HDLC logs
# MSE: 5.2 		at line	 328 	of the entire log file and at line	 38 	of the HDLC logs
# MSE: 5.8 		at line	 336 	of the entire log file and at line	 39 	of the HDLC logs
# MSE: 5.5 		at line	 347 	of the entire log file and at line	 40 	of the HDLC logs
# MSE: 6.7 		at line	 348 	of the entire log file and at line	 41 	of the HDLC logs
# MSE: 7.15 		at line	 350 	of the entire log file and at line	 42 	of the HDLC logs
# MSE: 5.6 		at line	 351 	of the entire log file and at line	 43 	of the HDLC logs
# MSE: 6.5 		at line	 352 	of the entire log file and at line	 44 	of the HDLC logs
# MSE: 7.35 		at line	 353 	of the entire log file and at line	 45 	of the HDLC logs
# MSE: 8.15 		at line	 359 	of the entire log file and at line	 46 	of the HDLC logs
# MSE: 8.75 		at line	 367 	of the entire log file and at line	 47 	of the HDLC logs
# MSE: 9.25 		at line	 368 	of the entire log file and at line	 48 	of the HDLC logs
# MSE: 12.85 		at line	 370 	of the entire log file and at line	 49 	of the HDLC logs
# MSE: 9.85 		at line	 371 	of the entire log file and at line	 50 	of the HDLC logs
# MSE: 8.55 		at line	 375 	of the entire log file and at line	 51 	of the HDLC logs
# MSE: 10.3 		at line	 376 	of the entire log file and at line	 52 	of the HDLC logs
# MSE: 7.15 		at line	 377 	of the entire log file and at line	 53 	of the HDLC logs
# MSE: 0.85 		at line	 378 	of the entire log file and at line	 54 	of the HDLC logs
# MSE: 1.85 		at line	 380 	of the entire log file and at line	 55 	of the HDLC logs
# MSE: 0.8 		at line	 383 	of the entire log file and at line	 56 	of the HDLC logs
# MSE: 0.25 		at line	 404 	of the entire log file and at line	 57 	of the HDLC logs
# MSE: 0.75 		at line	 407 	of the entire log file and at line	 58 	of the HDLC logs
# MSE: 1.05 		at line	 408 	of the entire log file and at line	 59 	of the HDLC logs
# MSE: 1.0 		at line	 419 	of the entire log file and at line	 60 	of the HDLC logs
# MSE: 0.85 		at line	 420 	of the entire log file and at line	 61 	of the HDLC logs
# MSE: 0.05 		at line	 422 	of the entire log file and at line	 62 	of the HDLC logs
# MSE: 1.75 		at line	 423 	of the entire log file and at line	 63 	of the HDLC logs
# MSE: 1.3 		at line	 437 	of the entire log file and at line	 64 	of the HDLC logs
# MSE: 0.1 		at line	 438 	of the entire log file and at line	 65 	of the HDLC logs
# MSE: 0.65 		at line	 442 	of the entire log file and at line	 66 	of the HDLC logs
# MSE: 2.05 		at line	 443 	of the entire log file and at line	 67 	of the HDLC logs
# MSE: 2.45 		at line	 448 	of the entire log file and at line	 68 	of the HDLC logs
# MSE: 1.2 		at line	 449 	of the entire log file and at line	 69 	of the HDLC logs
# MSE: 2.05 		at line	 450 	of the entire log file and at line	 70 	of the HDLC logs
# MSE: 0.75 		at line	 451 	of the entire log file and at line	 71 	of the HDLC logs
# MSE: 0.85 		at line	 460 	of the entire log file and at line	 72 	of the HDLC logs
# MSE: 1.55 		at line	 476 	of the entire log file and at line	 73 	of the HDLC logs
# MSE: 2.7 		at line	 477 	of the entire log file and at line	 74 	of the HDLC logs
# MSE: 2.7 		at line	 480 	of the entire log file and at line	 75 	of the HDLC logs
# MSE: 1.55 		at line	 481 	of the entire log file and at line	 76 	of the HDLC logs
# MSE: 2.2 		at line	 482 	of the entire log file and at line	 77 	of the HDLC logs
# MSE: 1.55 		at line	 483 	of the entire log file and at line	 78 	of the HDLC logs
# MSE: 1.7 		at line	 494 	of the entire log file and at line	 79 	of the HDLC logs
# MSE: 2.9 		at line	 502 	of the entire log file and at line	 80 	of the HDLC logs
# MSE: 8.2 		at line	 503 	of the entire log file and at line	 81 	of the HDLC logs
# MSE: 10.15 		at line	 505 	of the entire log file and at line	 82 	of the HDLC logs
# MSE: 1.9 		at line	 506 	of the entire log file and at line	 83 	of the HDLC logs
# MSE: 2.3 		at line	 507 	of the entire log file and at line	 84 	of the HDLC logs
# MSE: 1.25 		at line	 508 	of the entire log file and at line	 85 	of the HDLC logs
# MSE: 1.85 		at line	 512 	of the entire log file and at line	 86 	of the HDLC logs
# MSE: 1.85 		at line	 513 	of the entire log file and at line	 87 	of the HDLC logs
# MSE: 2.15 		at line	 515 	of the entire log file and at line	 88 	of the HDLC logs
# MSE: 1.3 		at line	 518 	of the entire log file and at line	 89 	of the HDLC logs
# MSE: 1.6 		at line	 541 	of the entire log file and at line	 90 	of the HDLC logs
# MSE: 1.9 		at line	 542 	of the entire log file and at line	 91 	of the HDLC logs
# MSE: 1.85 		at line	 553 	of the entire log file and at line	 92 	of the HDLC logs
# MSE: 1.7 		at line	 554 	of the entire log file and at line	 93 	of the HDLC logs
# MSE: 1.35 		at line	 556 	of the entire log file and at line	 94 	of the HDLC logs
# MSE: 3.4 		at line	 557 	of the entire log file and at line	 95 	of the HDLC logs
# MSE: 2.6 		at line	 571 	of the entire log file and at line	 96 	of the HDLC logs
# MSE: 2.3 		at line	 572 	of the entire log file and at line	 97 	of the HDLC logs
# MSE: 2.0 		at line	 573 	of the entire log file and at line	 98 	of the HDLC logs
# MSE: 3.55 		at line	 574 	of the entire log file and at line	 99 	of the HDLC logs
# MSE: 4.0 		at line	 579 	of the entire log file and at line	 100 	of the HDLC logs
# MSE: 2.2 		at line	 580 	of the entire log file and at line	 101 	of the HDLC logs
# MSE: 2.35 		at line	 581 	of the entire log file and at line	 102 	of the HDLC logs
# MSE: 2.5 		at line	 582 	of the entire log file and at line	 103 	of the HDLC logs
# MSE: 3.55 		at line	 592 	of the entire log file and at line	 104 	of the HDLC logs
# MSE: 3.25 		at line	 604 	of the entire log file and at line	 105 	of the HDLC logs
# MSE: 4.8 		at line	 605 	of the entire log file and at line	 106 	of the HDLC logs
# MSE: 2.05 		at line	 614 	of the entire log file and at line	 107 	of the HDLC logs
# MSE: 2.55 		at line	 615 	of the entire log file and at line	 108 	of the HDLC logs
# MSE: 3.4 		at line	 624 	of the entire log file and at line	 109 	of the HDLC logs
# MSE: 1.35 		at line	 625 	of the entire log file and at line	 110 	of the HDLC logs
# MSE: 3.25 		at line	 626 	of the entire log file and at line	 111 	of the HDLC logs
# MSE: 4.8 		at line	 627 	of the entire log file and at line	 112 	of the HDLC logs
# MSE: 2.05 		at line	 636 	of the entire log file and at line	 113 	of the HDLC logs
# MSE: 2.55 		at line	 637 	of the entire log file and at line	 114 	of the HDLC logs
# MSE: 3.4 		at line	 646 	of the entire log file and at line	 115 	of the HDLC logs
# MSE: 1.35 		at line	 647 	of the entire log file and at line	 116 	of the HDLC logs
# MSE: 3.2 		at line	 648 	of the entire log file and at line	 117 	of the HDLC logs
# MSE: 4.6 		at line	 649 	of the entire log file and at line	 118 	of the HDLC logs
# MSE: 0.75 		at line	 658 	of the entire log file and at line	 119 	of the HDLC logs
# MSE: 3.85 		at line	 659 	of the entire log file and at line	 120 	of the HDLC logs
# MSE: 2.1 		at line	 668 	of the entire log file and at line	 121 	of the HDLC logs
# MSE: 2.7 		at line	 669 	of the entire log file and at line	 122 	of the HDLC logs
# MSE: 3.5 		at line	 670 	of the entire log file and at line	 123 	of the HDLC logs
# MSE: 3.5 		at line	 671 	of the entire log file and at line	 124 	of the HDLC logs
# MSE: 2.3 		at line	 680 	of the entire log file and at line	 125 	of the HDLC logs
# MSE: 4.4 		at line	 681 	of the entire log file and at line	 126 	of the HDLC logs
# MSE: 3.65 		at line	 690 	of the entire log file and at line	 127 	of the HDLC logs
# MSE: 1.35 		at line	 691 	of the entire log file and at line	 128 	of the HDLC logs
# MSE: 1.6 		at line	 692 	of the entire log file and at line	 129 	of the HDLC logs
# MSE: 3.6 		at line	 693 	of the entire log file and at line	 130 	of the HDLC logs
# MSE: 0.5 		at line	 702 	of the entire log file and at line	 131 	of the HDLC logs
# MSE: 3.4 		at line	 703 	of the entire log file and at line	 132 	of the HDLC logs
# MSE: 2.6 		at line	 712 	of the entire log file and at line	 133 	of the HDLC logs
# MSE: 2.3 		at line	 713 	of the entire log file and at line	 134 	of the HDLC logs
# MSE: 2.0 		at line	 714 	of the entire log file and at line	 135 	of the HDLC logs
# MSE: 3.55 		at line	 715 	of the entire log file and at line	 136 	of the HDLC logs
# MSE: 4.0 		at line	 717 	of the entire log file and at line	 137 	of the HDLC logs
# MSE: 2.2 		at line	 718 	of the entire log file and at line	 138 	of the HDLC logs
# MSE: 2.35 		at line	 719 	of the entire log file and at line	 139 	of the HDLC logs
# MSE: 2.5 		at line	 720 	of the entire log file and at line	 140 	of the HDLC logs
# MSE: 3.55 		at line	 844 	of the entire log file and at line	 141 	of the HDLC logs
# MSE: 3.2 		at line	 856 	of the entire log file and at line	 142 	of the HDLC logs
# MSE: 4.6 		at line	 857 	of the entire log file and at line	 143 	of the HDLC logs
# MSE: 0.75 		at line	 866 	of the entire log file and at line	 144 	of the HDLC logs
# MSE: 3.85 		at line	 867 	of the entire log file and at line	 145 	of the HDLC logs
# MSE: 2.1 		at line	 876 	of the entire log file and at line	 146 	of the HDLC logs
# MSE: 2.7 		at line	 877 	of the entire log file and at line	 147 	of the HDLC logs
# MSE: 3.5 		at line	 878 	of the entire log file and at line	 148 	of the HDLC logs
# MSE: 3.5 		at line	 879 	of the entire log file and at line	 149 	of the HDLC logs
# MSE: 2.3 		at line	 888 	of the entire log file and at line	 150 	of the HDLC logs
# MSE: 4.4 		at line	 889 	of the entire log file and at line	 151 	of the HDLC logs
# MSE: 3.65 		at line	 898 	of the entire log file and at line	 152 	of the HDLC logs
# MSE: 1.35 		at line	 899 	of the entire log file and at line	 153 	of the HDLC logs
# MSE: 1.6 		at line	 900 	of the entire log file and at line	 154 	of the HDLC logs
# MSE: 3.55 		at line	 901 	of the entire log file and at line	 155 	of the HDLC logs
# MSE: 1.8 		at line	 910 	of the entire log file and at line	 156 	of the HDLC logs
# MSE: 2.7 		at line	 911 	of the entire log file and at line	 157 	of the HDLC logs
# MSE: 2.25 		at line	 920 	of the entire log file and at line	 158 	of the HDLC logs
# MSE: 0.95 		at line	 921 	of the entire log file and at line	 159 	of the HDLC logs
# MSE: 1.7 		at line	 922 	of the entire log file and at line	 160 	of the HDLC logs
# MSE: 3.35 		at line	 923 	of the entire log file and at line	 161 	of the HDLC logs
# MSE: 4.55 		at line	 932 	of the entire log file and at line	 162 	of the HDLC logs
# MSE: 2.95 		at line	 933 	of the entire log file and at line	 163 	of the HDLC logs
# MSE: 4.25 		at line	 934 	of the entire log file and at line	 164 	of the HDLC logs
# MSE: 4.25 		at line	 935 	of the entire log file and at line	 165 	of the HDLC logs
# MSE: 2.1 		at line	 1033 	of the entire log file and at line	 166 	of the HDLC logs
# MSE: 1.6 		at line	 1045 	of the entire log file and at line	 167 	of the HDLC logs
# MSE: 3.55 		at line	 1046 	of the entire log file and at line	 168 	of the HDLC logs
# MSE: 1.8 		at line	 1055 	of the entire log file and at line	 169 	of the HDLC logs
# MSE: 2.7 		at line	 1056 	of the entire log file and at line	 170 	of the HDLC logs
# MSE: 2.25 		at line	 1065 	of the entire log file and at line	 171 	of the HDLC logs
# MSE: 0.95 		at line	 1066 	of the entire log file and at line	 172 	of the HDLC logs
# MSE: 1.7 		at line	 1067 	of the entire log file and at line	 173 	of the HDLC logs
# MSE: 3.35 		at line	 1068 	of the entire log file and at line	 174 	of the HDLC logs
# MSE: 4.55 		at line	 1072 	of the entire log file and at line	 175 	of the HDLC logs
# MSE: 2.95 		at line	 1073 	of the entire log file and at line	 176 	of the HDLC logs
# MSE: 4.25 		at line	 1074 	of the entire log file and at line	 177 	of the HDLC logs
# MSE: 4.25 		at line	 1087 	of the entire log file and at line	 178 	of the HDLC logs
# MSE: 2.1 		at line	 1106 	of the entire log file and at line	 179 	of the HDLC logs
# MSE: 1.6 		at line	 1118 	of the entire log file and at line	 180 	of the HDLC logs
# MSE: 3.55 		at line	 1119 	of the entire log file and at line	 181 	of the HDLC logs
# MSE: 1.8 		at line	 1128 	of the entire log file and at line	 182 	of the HDLC logs
# MSE: 2.7 		at line	 1129 	of the entire log file and at line	 183 	of the HDLC logs
# MSE: 2.25 		at line	 1138 	of the entire log file and at line	 184 	of the HDLC logs
# MSE: 0.95 		at line	 1139 	of the entire log file and at line	 185 	of the HDLC logs
# MSE: 1.7 		at line	 1140 	of the entire log file and at line	 186 	of the HDLC logs
# MSE: 3.35 		at line	 1141 	of the entire log file and at line	 187 	of the HDLC logs
# MSE: 4.7 		at line	 1148 	of the entire log file and at line	 188 	of the HDLC logs
# MSE: 2.6 		at line	 1149 	of the entire log file and at line	 189 	of the HDLC logs
# MSE: 4.0 		at line	 1150 	of the entire log file and at line	 190 	of the HDLC logs
# MSE: 4.3 		at line	 1165 	of the entire log file and at line	 191 	of the HDLC logs
# MSE: 2.95 		at line	 1197 	of the entire log file and at line	 192 	of the HDLC logs
# MSE: 2.45 		at line	 1209 	of the entire log file and at line	 193 	of the HDLC logs
# MSE: 4.4 		at line	 1210 	of the entire log file and at line	 194 	of the HDLC logs
# MSE: 0.55 		at line	 1219 	of the entire log file and at line	 195 	of the HDLC logs
# MSE: 3.05 		at line	 1220 	of the entire log file and at line	 196 	of the HDLC logs
# MSE: 2.6 		at line	 1229 	of the entire log file and at line	 197 	of the HDLC logs
# MSE: 1.4 		at line	 1230 	of the entire log file and at line	 198 	of the HDLC logs
# MSE: 1.35 		at line	 1231 	of the entire log file and at line	 199 	of the HDLC logs
# MSE: 3.35 		at line	 1232 	of the entire log file and at line	 200 	of the HDLC logs
# MSE: 2.55 		at line	 1237 	of the entire log file and at line	 201 	of the HDLC logs
# MSE: 1.75 		at line	 1238 	of the entire log file and at line	 202 	of the HDLC logs
# MSE: 2.15 		at line	 1239 	of the entire log file and at line	 203 	of the HDLC logs
# MSE: 0.75 		at line	 1283 	of the entire log file and at line	 204 	of the HDLC logs
# MSE: 1.3 		at line	 1284 	of the entire log file and at line	 205 	of the HDLC logs
# MSE: 1.35 		at line	 1296 	of the entire log file and at line	 206 	of the HDLC logs
# MSE: 3.35 		at line	 1297 	of the entire log file and at line	 207 	of the HDLC logs
# MSE: 2.55 		at line	 1303 	of the entire log file and at line	 208 	of the HDLC logs
# MSE: 1.75 		at line	 1304 	of the entire log file and at line	 209 	of the HDLC logs
# MSE: 2.15 		at line	 1305 	of the entire log file and at line	 210 	of the HDLC logs
# MSE: 0.75 		at line	 1318 	of the entire log file and at line	 211 	of the HDLC logs
# MSE: 1.3 		at line	 1323 	of the entire log file and at line	 212 	of the HDLC logs
# MSE: 1.35 		at line	 1335 	of the entire log file and at line	 213 	of the HDLC logs
# MSE: 3.35 		at line	 1336 	of the entire log file and at line	 214 	of the HDLC logs
# MSE: 2.55 		at line	 1338 	of the entire log file and at line	 215 	of the HDLC logs
# MSE: 1.75 		at line	 1339 	of the entire log file and at line	 216 	of the HDLC logs
# MSE: 2.15 		at line	 1340 	of the entire log file and at line	 217 	of the HDLC logs
# MSE: 0.75 		at line	 1341 	of the entire log file and at line	 218 	of the HDLC logs
# MSE: 1.3 		at line	 1352 	of the entire log file and at line	 219 	of the HDLC logs
# MSE: 1.35 		at line	 1364 	of the entire log file and at line	 220 	of the HDLC logs
# MSE: 3.35 		at line	 1365 	of the entire log file and at line	 221 	of the HDLC logs
# MSE: 2.55 		at line	 1373 	of the entire log file and at line	 222 	of the HDLC logs
# MSE: 1.75 		at line	 1374 	of the entire log file and at line	 223 	of the HDLC logs
# MSE: 2.15 		at line	 1375 	of the entire log file and at line	 224 	of the HDLC logs
# MSE: 0.75 		at line	 1383 	of the entire log file and at line	 225 	of the HDLC logs
# MSE: 1.3 		at line	 1402 	of the entire log file and at line	 226 	of the HDLC logs
# MSE: 1.35 		at line	 1414 	of the entire log file and at line	 227 	of the HDLC logs
# MSE: 5.8 		at line	 1415 	of the entire log file and at line	 228 	of the HDLC logs
# MSE: 5.8 		at line	 1422 	of the entire log file and at line	 229 	of the HDLC logs
# MSE: 4.75 		at line	 1423 	of the entire log file and at line	 230 	of the HDLC logs
# MSE: 8.65 		at line	 1424 	of the entire log file and at line	 231 	of the HDLC logs
# MSE: 10.45 		at line	 1431 	of the entire log file and at line	 232 	of the HDLC logs
# MSE: 11.05 		at line	 1449 	of the entire log file and at line	 233 	of the HDLC logs
# MSE: 8.25 		at line	 1461 	of the entire log file and at line	 234 	of the HDLC logs
# MSE: 10.3 		at line	 1462 	of the entire log file and at line	 235 	of the HDLC logs
# MSE: 14.9 		at line	 1466 	of the entire log file and at line	 236 	of the HDLC logs
# MSE: 14.85 		at line	 1467 	of the entire log file and at line	 237 	of the HDLC logs
# MSE: 17.85 		at line	 1468 	of the entire log file and at line	 238 	of the HDLC logs
# MSE: 18.2 		at line	 1469 	of the entire log file and at line	 239 	of the HDLC logs
# MSE: 20.9 		at line	 1481 	of the entire log file and at line	 240 	of the HDLC logs
# MSE: 21.9 		at line	 1493 	of the entire log file and at line	 241 	of the HDLC logs
# MSE: 21.5 		at line	 1494 	of the entire log file and at line	 242 	of the HDLC logs
# MSE: 25.2 		at line	 1496 	of the entire log file and at line	 243 	of the HDLC logs
#
# Passed threshold at around line 1496
# MSE: 21.9 		at line	 1497 	of the entire log file and at line	 244 	of the HDLC logs
# MSE: 26.95 		at line	 1498 	of the entire log file and at line	 245 	of the HDLC logs
# MSE: 25.8 		at line	 1499 	of the entire log file and at line	 246 	of the HDLC logs
# MSE: 30.35 		at line	 1510 	of the entire log file and at line	 247 	of the HDLC logs
# MSE: 35.05 		at line	 1539 	of the entire log file and at line	 248 	of the HDLC logs
# MSE: 32.6 		at line	 1540 	of the entire log file and at line	 249 	of the HDLC logs
# MSE: 25.8 		at line	 1541 	of the entire log file and at line	 250 	of the HDLC logs
# MSE: 41.7 		at line	 1542 	of the entire log file and at line	 251 	of the HDLC logs
# MSE: 36.25 		at line	 1543 	of the entire log file and at line	 252 	of the HDLC logs
# MSE: 44.4 		at line	 1544 	of the entire log file and at line	 253 	of the HDLC logs
# MSE: 45.5 		at line	 1552 	of the entire log file and at line	 254 	of the HDLC logs
# MSE: 46.7 		at line	 1553 	of the entire log file and at line	 255 	of the HDLC logs
# MSE: 49.75 		at line	 1581 	of the entire log file and at line	 256 	of the HDLC logs
# MSE: 31.8 		at line	 1582 	of the entire log file and at line	 257 	of the HDLC logs
# MSE: 17.95 		at line	 1583 	of the entire log file and at line	 258 	of the HDLC logs
# MSE: 32.3 		at line	 1584 	of the entire log file and at line	 259 	of the HDLC logs
# MSE: 23.25 		at line	 1585 	of the entire log file and at line	 260 	of the HDLC logs
# MSE: 21.6 		at line	 1592 	of the entire log file and at line	 261 	of the HDLC logs
# MSE: 18.5 		at line	 1593 	of the entire log file and at line	 262 	of the HDLC logs
# MSE: 22.75 		at line	 1617 	of the entire log file and at line	 263 	of the HDLC logs
# MSE: 34.3 		at line	 1618 	of the entire log file and at line	 264 	of the HDLC logs
# MSE: 31.05 		at line	 1619 	of the entire log file and at line	 265 	of the HDLC logs
# MSE: 37.3 		at line	 1623 	of the entire log file and at line	 266 	of the HDLC logs
# MSE: 33.55 		at line	 1624 	of the entire log file and at line	 267 	of the HDLC logs
# MSE: 37.9 		at line	 1626 	of the entire log file and at line	 268 	of the HDLC logs
# MSE: 37.4 		at line	 1627 	of the entire log file and at line	 269 	of the HDLC logs
# MSE: 36.8 		at line	 1655 	of the entire log file and at line	 270 	of the HDLC logs
# MSE: 33.3 		at line	 1656 	of the entire log file and at line	 271 	of the HDLC logs
# MSE: 17.1 		at line	 1657 	of the entire log file and at line	 272 	of the HDLC logs
# MSE: 23.2 		at line	 1658 	of the entire log file and at line	 273 	of the HDLC logs
# MSE: 18.9 		at line	 1659 	of the entire log file and at line	 274 	of the HDLC logs
# MSE: 27.15 		at line	 1662 	of the entire log file and at line	 275 	of the HDLC logs
# MSE: 26.95 		at line	 1663 	of the entire log file and at line	 276 	of the HDLC logs
# MSE: 24.3 		at line	 1694 	of the entire log file and at line	 277 	of the HDLC logs
# MSE: 21.9 		at line	 1695 	of the entire log file and at line	 278 	of the HDLC logs
# MSE: 27.45 		at line	 1697 	of the entire log file and at line	 279 	of the HDLC logs
# MSE: 36.25 		at line	 1700 	of the entire log file and at line	 280 	of the HDLC logs
# MSE: 32.55 		at line	 1721 	of the entire log file and at line	 281 	of the HDLC logs
# MSE: 31.15 		at line	 1724 	of the entire log file and at line	 282 	of the HDLC logs
# MSE: 34.9 		at line	 1725 	of the entire log file and at line	 283 	of the HDLC logs
# MSE: 43.6 		at line	 1740 	of the entire log file and at line	 284 	of the HDLC logs
# MSE: 35.4 		at line	 1741 	of the entire log file and at line	 285 	of the HDLC logs
# MSE: 30.45 		at line	 1742 	of the entire log file and at line	 286 	of the HDLC logs
# MSE: 49.4 		at line	 1743 	of the entire log file and at line	 287 	of the HDLC logs
# MSE: 41.6 		at line	 1744 	of the entire log file and at line	 288 	of the HDLC logs
# MSE: 43.05 		at line	 1747 	of the entire log file and at line	 289 	of the HDLC logs
# MSE: 41.55 		at line	 1748 	of the entire log file and at line	 290 	of the HDLC logs
# MSE: 42.35 		at line	 1780 	of the entire log file and at line	 291 	of the HDLC logs
# MSE: 39.95 		at line	 1781 	of the entire log file and at line	 292 	of the HDLC logs
# MSE: 16.8 		at line	 1782 	of the entire log file and at line	 293 	of the HDLC logs
# MSE: 24.0 		at line	 1783 	of the entire log file and at line	 294 	of the HDLC logs
# MSE: 24.7 		at line	 1784 	of the entire log file and at line	 295 	of the HDLC logs
# MSE: 32.3 		at line	 1787 	of the entire log file and at line	 296 	of the HDLC logs
# MSE: 29.95 		at line	 1788 	of the entire log file and at line	 297 	of the HDLC logs
# MSE: 27.1 		at line	 1798 	of the entire log file and at line	 298 	of the HDLC logs
# MSE: 24.3 		at line	 1799 	of the entire log file and at line	 299 	of the HDLC logs
# MSE: 29.1 		at line	 1801 	of the entire log file and at line	 300 	of the HDLC logs
# MSE: 27.0 		at line	 1804 	of the entire log file and at line	 301 	of the HDLC logs
# MSE: 24.65 		at line	 1827 	of the entire log file and at line	 302 	of the HDLC logs
# MSE: 30.5 		at line	 1828 	of the entire log file and at line	 303 	of the HDLC logs
# MSE: 31.7 		at line	 1856 	of the entire log file and at line	 304 	of the HDLC logs
# MSE: 23.85 		at line	 1857 	of the entire log file and at line	 305 	of the HDLC logs
# MSE: 17.15 		at line	 1858 	of the entire log file and at line	 306 	of the HDLC logs
# MSE: 28.7 		at line	 1859 	of the entire log file and at line	 307 	of the HDLC logs
# MSE: 29.65 		at line	 1860 	of the entire log file and at line	 308 	of the HDLC logs
# MSE: 29.1 		at line	 1863 	of the entire log file and at line	 309 	of the HDLC logs
# MSE: 31.25 		at line	 1864 	of the entire log file and at line	 310 	of the HDLC logs
# MSE: 32.75 		at line	 1896 	of the entire log file and at line	 311 	of the HDLC logs
# MSE: 20.9 		at line	 1897 	of the entire log file and at line	 312 	of the HDLC logs
# MSE: 18.85 		at line	 1898 	of the entire log file and at line	 313 	of the HDLC logs
# MSE: 20.1 		at line	 1899 	of the entire log file and at line	 314 	of the HDLC logs
# MSE: 20.25 		at line	 1900 	of the entire log file and at line	 315 	of the HDLC logs
# MSE: 20.45 		at line	 1903 	of the entire log file and at line	 316 	of the HDLC logs
# MSE: 24.2 		at line	 1904 	of the entire log file and at line	 317 	of the HDLC logs
# MSE: 25.1 		at line	 1914 	of the entire log file and at line	 318 	of the HDLC logs
# MSE: 17.9 		at line	 1915 	of the entire log file and at line	 319 	of the HDLC logs
# MSE: 22.75 		at line	 1934 	of the entire log file and at line	 320 	of the HDLC logs
# MSE: 34.3 		at line	 1935 	of the entire log file and at line	 321 	of the HDLC logs
# MSE: 31.05 		at line	 1936 	of the entire log file and at line	 322 	of the HDLC logs
# MSE: 37.3 		at line	 1940 	of the entire log file and at line	 323 	of the HDLC logs
# MSE: 33.55 		at line	 1941 	of the entire log file and at line	 324 	of the HDLC logs
# MSE: 37.9 		at line	 1943 	of the entire log file and at line	 325 	of the HDLC logs
# MSE: 37.4 		at line	 1944 	of the entire log file and at line	 326 	of the HDLC logs
# MSE: 36.8 		at line	 1980 	of the entire log file and at line	 327 	of the HDLC logs
# MSE: 33.3 		at line	 1981 	of the entire log file and at line	 328 	of the HDLC logs
# MSE: 17.1 		at line	 1982 	of the entire log file and at line	 329 	of the HDLC logs
# MSE: 23.2 		at line	 1983 	of the entire log file and at line	 330 	of the HDLC logs
# MSE: 18.9 		at line	 1984 	of the entire log file and at line	 331 	of the HDLC logs
# MSE: 27.15 		at line	 1987 	of the entire log file and at line	 332 	of the HDLC logs
# MSE: 26.95 		at line	 1988 	of the entire log file and at line	 333 	of the HDLC logs
# MSE: 24.3 		at line	 2015 	of the entire log file and at line	 334 	of the HDLC logs
# MSE: 21.9 		at line	 2016 	of the entire log file and at line	 335 	of the HDLC logs
# MSE: 27.45 		at line	 2018 	of the entire log file and at line	 336 	of the HDLC logs
# MSE: 36.25 		at line	 2021 	of the entire log file and at line	 337 	of the HDLC logs
# MSE: 32.55 		at line	 2042 	of the entire log file and at line	 338 	of the HDLC logs
# MSE: 31.15 		at line	 2045 	of the entire log file and at line	 339 	of the HDLC logs
# MSE: 34.9 		at line	 2046 	of the entire log file and at line	 340 	of the HDLC logs
# MSE: 43.6 		at line	 2062 	of the entire log file and at line	 341 	of the HDLC logs
# MSE: 35.4 		at line	 2063 	of the entire log file and at line	 342 	of the HDLC logs
# MSE: 30.45 		at line	 2064 	of the entire log file and at line	 343 	of the HDLC logs
# MSE: 49.4 		at line	 2065 	of the entire log file and at line	 344 	of the HDLC logs
# MSE: 41.6 		at line	 2066 	of the entire log file and at line	 345 	of the HDLC logs
# MSE: 43.05 		at line	 2069 	of the entire log file and at line	 346 	of the HDLC logs
# MSE: 41.55 		at line	 2070 	of the entire log file and at line	 347 	of the HDLC logs
# MSE: 42.35 		at line	 2097 	of the entire log file and at line	 348 	of the HDLC logs
# MSE: 39.95 		at line	 2098 	of the entire log file and at line	 349 	of the HDLC logs
# MSE: 16.8 		at line	 2099 	of the entire log file and at line	 350 	of the HDLC logs
# MSE: 24.0 		at line	 2100 	of the entire log file and at line	 351 	of the HDLC logs
# MSE: 24.7 		at line	 2101 	of the entire log file and at line	 352 	of the HDLC logs
# MSE: 32.3 		at line	 2104 	of the entire log file and at line	 353 	of the HDLC logs
# MSE: 29.95 		at line	 2105 	of the entire log file and at line	 354 	of the HDLC logs
# MSE: 27.1 		at line	 2119 	of the entire log file and at line	 355 	of the HDLC logs
# MSE: 24.3 		at line	 2120 	of the entire log file and at line	 356 	of the HDLC logs
# MSE: 29.1 		at line	 2122 	of the entire log file and at line	 357 	of the HDLC logs
# MSE: 27.0 		at line	 2125 	of the entire log file and at line	 358 	of the HDLC logs
# MSE: 24.65 		at line	 2148 	of the entire log file and at line	 359 	of the HDLC logs
# MSE: 30.5 		at line	 2149 	of the entire log file and at line	 360 	of the HDLC logs
# MSE: 31.7 		at line	 2177 	of the entire log file and at line	 361 	of the HDLC logs
# MSE: 23.85 		at line	 2178 	of the entire log file and at line	 362 	of the HDLC logs
# MSE: 17.15 		at line	 2179 	of the entire log file and at line	 363 	of the HDLC logs
# MSE: 28.7 		at line	 2180 	of the entire log file and at line	 364 	of the HDLC logs
# MSE: 29.65 		at line	 2181 	of the entire log file and at line	 365 	of the HDLC logs
# MSE: 29.1 		at line	 2184 	of the entire log file and at line	 366 	of the HDLC logs
# MSE: 31.25 		at line	 2185 	of the entire log file and at line	 367 	of the HDLC logs
# MSE: 32.75 		at line	 2212 	of the entire log file and at line	 368 	of the HDLC logs
# MSE: 20.9 		at line	 2213 	of the entire log file and at line	 369 	of the HDLC logs
# MSE: 18.85 		at line	 2214 	of the entire log file and at line	 370 	of the HDLC logs
# MSE: 20.1 		at line	 2215 	of the entire log file and at line	 371 	of the HDLC logs
# MSE: 20.25 		at line	 2216 	of the entire log file and at line	 372 	of the HDLC logs
# MSE: 20.45 		at line	 2219 	of the entire log file and at line	 373 	of the HDLC logs
# MSE: 24.2 		at line	 2220 	of the entire log file and at line	 374 	of the HDLC logs
# MSE: 25.1 		at line	 2230 	of the entire log file and at line	 375 	of the HDLC logs
# MSE: 17.9 		at line	 2231 	of the entire log file and at line	 376 	of the HDLC logs
# MSE: 22.75 		at line	 2254 	of the entire log file and at line	 377 	of the HDLC logs
# MSE: 34.3 		at line	 2255 	of the entire log file and at line	 378 	of the HDLC logs
# MSE: 31.05 		at line	 2256 	of the entire log file and at line	 379 	of the HDLC logs
# MSE: 37.3 		at line	 2264 	of the entire log file and at line	 380 	of the HDLC logs
# MSE: 33.55 		at line	 2265 	of the entire log file and at line	 381 	of the HDLC logs
# MSE: 37.9 		at line	 2267 	of the entire log file and at line	 382 	of the HDLC logs
# MSE: 37.4 		at line	 2268 	of the entire log file and at line	 383 	of the HDLC logs
# MSE: 36.8 		at line	 2297 	of the entire log file and at line	 384 	of the HDLC logs
# MSE: 33.3 		at line	 2298 	of the entire log file and at line	 385 	of the HDLC logs
# MSE: 17.1 		at line	 2299 	of the entire log file and at line	 386 	of the HDLC logs
# MSE: 23.2 		at line	 2300 	of the entire log file and at line	 387 	of the HDLC logs
# MSE: 18.9 		at line	 2301 	of the entire log file and at line	 388 	of the HDLC logs
# MSE: 27.15 		at line	 2304 	of the entire log file and at line	 389 	of the HDLC logs
# MSE: 26.95 		at line	 2305 	of the entire log file and at line	 390 	of the HDLC logs
# MSE: 24.3 		at line	 2328 	of the entire log file and at line	 391 	of the HDLC logs
# MSE: 21.9 		at line	 2329 	of the entire log file and at line	 392 	of the HDLC logs
# MSE: 27.45 		at line	 2331 	of the entire log file and at line	 393 	of the HDLC logs
# MSE: 36.25 		at line	 2334 	of the entire log file and at line	 394 	of the HDLC logs
# MSE: 32.55 		at line	 2355 	of the entire log file and at line	 395 	of the HDLC logs
# MSE: 31.15 		at line	 2358 	of the entire log file and at line	 396 	of the HDLC logs
# MSE: 34.9 		at line	 2359 	of the entire log file and at line	 397 	of the HDLC logs
# MSE: 43.6 		at line	 2370 	of the entire log file and at line	 398 	of the HDLC logs
# MSE: 35.4 		at line	 2371 	of the entire log file and at line	 399 	of the HDLC logs
# MSE: 30.45 		at line	 2372 	of the entire log file and at line	 400 	of the HDLC logs
# MSE: 49.4 		at line	 2373 	of the entire log file and at line	 401 	of the HDLC logs
# MSE: 41.6 		at line	 2374 	of the entire log file and at line	 402 	of the HDLC logs
# MSE: 43.05 		at line	 2377 	of the entire log file and at line	 403 	of the HDLC logs
# MSE: 41.55 		at line	 2378 	of the entire log file and at line	 404 	of the HDLC logs
# MSE: 42.35 		at line	 2418 	of the entire log file and at line	 405 	of the HDLC logs
# MSE: 39.95 		at line	 2419 	of the entire log file and at line	 406 	of the HDLC logs
# MSE: 16.8 		at line	 2420 	of the entire log file and at line	 407 	of the HDLC logs
# MSE: 24.0 		at line	 2423 	of the entire log file and at line	 408 	of the HDLC logs
# MSE: 24.7 		at line	 2424 	of the entire log file and at line	 409 	of the HDLC logs
# MSE: 32.3 		at line	 2425 	of the entire log file and at line	 410 	of the HDLC logs
# MSE: 29.95 		at line	 2426 	of the entire log file and at line	 411 	of the HDLC logs
# MSE: 27.1 		at line	 2440 	of the entire log file and at line	 412 	of the HDLC logs
# MSE: 24.3 		at line	 2441 	of the entire log file and at line	 413 	of the HDLC logs
# MSE: 29.1 		at line	 2443 	of the entire log file and at line	 414 	of the HDLC logs
# MSE: 27.0 		at line	 2446 	of the entire log file and at line	 415 	of the HDLC logs
# MSE: 24.65 		at line	 2469 	of the entire log file and at line	 416 	of the HDLC logs
# MSE: 30.5 		at line	 2470 	of the entire log file and at line	 417 	of the HDLC logs
# MSE: 31.7 		at line	 2494 	of the entire log file and at line	 418 	of the HDLC logs
# MSE: 23.85 		at line	 2495 	of the entire log file and at line	 419 	of the HDLC logs
# MSE: 17.15 		at line	 2496 	of the entire log file and at line	 420 	of the HDLC logs
# MSE: 28.7 		at line	 2497 	of the entire log file and at line	 421 	of the HDLC logs
# MSE: 29.65 		at line	 2498 	of the entire log file and at line	 422 	of the HDLC logs
# MSE: 29.1 		at line	 2501 	of the entire log file and at line	 423 	of the HDLC logs
# MSE: 31.25 		at line	 2502 	of the entire log file and at line	 424 	of the HDLC logs
# MSE: 32.75 		at line	 2533 	of the entire log file and at line	 425 	of the HDLC logs
# MSE: 20.9 		at line	 2534 	of the entire log file and at line	 426 	of the HDLC logs
# MSE: 18.85 		at line	 2535 	of the entire log file and at line	 427 	of the HDLC logs
# MSE: 20.1 		at line	 2536 	of the entire log file and at line	 428 	of the HDLC logs
# MSE: 20.25 		at line	 2537 	of the entire log file and at line	 429 	of the HDLC logs
# MSE: 20.45 		at line	 2540 	of the entire log file and at line	 430 	of the HDLC logs
# MSE: 24.2 		at line	 2541 	of the entire log file and at line	 431 	of the HDLC logs
# MSE: 25.1 		at line	 2551 	of the entire log file and at line	 432 	of the HDLC logs
# MSE: 17.9 		at line	 2552 	of the entire log file and at line	 433 	of the HDLC logs
# MSE: 22.75 		at line	 2575 	of the entire log file and at line	 434 	of the HDLC logs
# MSE: 34.3 		at line	 2576 	of the entire log file and at line	 435 	of the HDLC logs
# MSE: 31.05 		at line	 2577 	of the entire log file and at line	 436 	of the HDLC logs
# MSE: 37.3 		at line	 2581 	of the entire log file and at line	 437 	of the HDLC logs
# MSE: 33.55 		at line	 2582 	of the entire log file and at line	 438 	of the HDLC logs
# MSE: 37.9 		at line	 2584 	of the entire log file and at line	 439 	of the HDLC logs
# MSE: 37.4 		at line	 2585 	of the entire log file and at line	 440 	of the HDLC logs
# MSE: 36.8 		at line	 2609 	of the entire log file and at line	 441 	of the HDLC logs
# MSE: 33.3 		at line	 2610 	of the entire log file and at line	 442 	of the HDLC logs
# MSE: 17.1 		at line	 2611 	of the entire log file and at line	 443 	of the HDLC logs
# MSE: 23.2 		at line	 2612 	of the entire log file and at line	 444 	of the HDLC logs
# MSE: 18.9 		at line	 2613 	of the entire log file and at line	 445 	of the HDLC logs
# MSE: 27.15 		at line	 2616 	of the entire log file and at line	 446 	of the HDLC logs
# MSE: 26.95 		at line	 2617 	of the entire log file and at line	 447 	of the HDLC logs
# MSE: 24.3 		at line	 2652 	of the entire log file and at line	 448 	of the HDLC logs
# MSE: 21.9 		at line	 2653 	of the entire log file and at line	 449 	of the HDLC logs
# MSE: 27.45 		at line	 2655 	of the entire log file and at line	 450 	of the HDLC logs
# MSE: 36.25 		at line	 2658 	of the entire log file and at line	 451 	of the HDLC logs
# MSE: 32.55 		at line	 2679 	of the entire log file and at line	 452 	of the HDLC logs
# MSE: 31.15 		at line	 2682 	of the entire log file and at line	 453 	of the HDLC logs
# MSE: 34.9 		at line	 2683 	of the entire log file and at line	 454 	of the HDLC logs
# MSE: 43.6 		at line	 2694 	of the entire log file and at line	 455 	of the HDLC logs
# MSE: 35.4 		at line	 2695 	of the entire log file and at line	 456 	of the HDLC logs
# MSE: 30.45 		at line	 2696 	of the entire log file and at line	 457 	of the HDLC logs
# MSE: 49.4 		at line	 2697 	of the entire log file and at line	 458 	of the HDLC logs
# MSE: 41.6 		at line	 2698 	of the entire log file and at line	 459 	of the HDLC logs
# MSE: 43.05 		at line	 2701 	of the entire log file and at line	 460 	of the HDLC logs
# MSE: 41.55 		at line	 2702 	of the entire log file and at line	 461 	of the HDLC logs
# MSE: 42.35 		at line	 2735 	of the entire log file and at line	 462 	of the HDLC logs
# MSE: 39.95 		at line	 2736 	of the entire log file and at line	 463 	of the HDLC logs
# MSE: 16.8 		at line	 2737 	of the entire log file and at line	 464 	of the HDLC logs
# MSE: 24.0 		at line	 2738 	of the entire log file and at line	 465 	of the HDLC logs
# MSE: 24.7 		at line	 2739 	of the entire log file and at line	 466 	of the HDLC logs
# MSE: 32.3 		at line	 2742 	of the entire log file and at line	 467 	of the HDLC logs
# MSE: 29.95 		at line	 2743 	of the entire log file and at line	 468 	of the HDLC logs
# MSE: 27.1 		at line	 2753 	of the entire log file and at line	 469 	of the HDLC logs
# MSE: 24.3 		at line	 2754 	of the entire log file and at line	 470 	of the HDLC logs
# MSE: 29.1 		at line	 2756 	of the entire log file and at line	 471 	of the HDLC logs
# MSE: 27.0 		at line	 2759 	of the entire log file and at line	 472 	of the HDLC logs
# MSE: 24.65 		at line	 2782 	of the entire log file and at line	 473 	of the HDLC logs
# MSE: 30.5 		at line	 2783 	of the entire log file and at line	 474 	of the HDLC logs
# MSE: 31.7 		at line	 2815 	of the entire log file and at line	 475 	of the HDLC logs
# MSE: 23.85 		at line	 2816 	of the entire log file and at line	 476 	of the HDLC logs
# MSE: 17.15 		at line	 2817 	of the entire log file and at line	 477 	of the HDLC logs
# MSE: 28.7 		at line	 2818 	of the entire log file and at line	 478 	of the HDLC logs
# MSE: 29.65 		at line	 2819 	of the entire log file and at line	 479 	of the HDLC logs
# MSE: 29.1 		at line	 2822 	of the entire log file and at line	 480 	of the HDLC logs
# MSE: 31.25 		at line	 2823 	of the entire log file and at line	 481 	of the HDLC logs
# MSE: 32.75 		at line	 2854 	of the entire log file and at line	 482 	of the HDLC logs
# MSE: 20.9 		at line	 2855 	of the entire log file and at line	 483 	of the HDLC logs
# MSE: 18.85 		at line	 2856 	of the entire log file and at line	 484 	of the HDLC logs
# MSE: 20.1 		at line	 2857 	of the entire log file and at line	 485 	of the HDLC logs
# MSE: 20.25 		at line	 2858 	of the entire log file and at line	 486 	of the HDLC logs
# MSE: 20.45 		at line	 2861 	of the entire log file and at line	 487 	of the HDLC logs
# MSE: 24.2 		at line	 2862 	of the entire log file and at line	 488 	of the HDLC logs
# MSE: 25.1 		at line	 2872 	of the entire log file and at line	 489 	of the HDLC logs
# MSE: 17.9 		at line	 2873 	of the entire log file and at line	 490 	of the HDLC logs
# MSE: 22.75 		at line	 2888 	of the entire log file and at line	 491 	of the HDLC logs
# MSE: 34.3 		at line	 2889 	of the entire log file and at line	 492 	of the HDLC logs
# MSE: 31.05 		at line	 2890 	of the entire log file and at line	 493 	of the HDLC logs
# MSE: 37.3 		at line	 2894 	of the entire log file and at line	 494 	of the HDLC logs
# MSE: 33.55 		at line	 2895 	of the entire log file and at line	 495 	of the HDLC logs
# MSE: 37.9 		at line	 2897 	of the entire log file and at line	 496 	of the HDLC logs
# MSE: 37.4 		at line	 2898 	of the entire log file and at line	 497 	of the HDLC logs
# MSE: 36.8 		at line	 2934 	of the entire log file and at line	 498 	of the HDLC logs
# MSE: 33.3 		at line	 2935 	of the entire log file and at line	 499 	of the HDLC logs
# MSE: 17.1 		at line	 2936 	of the entire log file and at line	 500 	of the HDLC logs
# MSE: 23.2 		at line	 2937 	of the entire log file and at line	 501 	of the HDLC logs
# MSE: 18.9 		at line	 2938 	of the entire log file and at line	 502 	of the HDLC logs
# MSE: 27.15 		at line	 2941 	of the entire log file and at line	 503 	of the HDLC logs
# MSE: 26.95 		at line	 2942 	of the entire log file and at line	 504 	of the HDLC logs
# MSE: 24.3 		at line	 2969 	of the entire log file and at line	 505 	of the HDLC logs
# MSE: 21.9 		at line	 2970 	of the entire log file and at line	 506 	of the HDLC logs
# MSE: 27.45 		at line	 2972 	of the entire log file and at line	 507 	of the HDLC logs
# MSE: 36.25 		at line	 2975 	of the entire log file and at line	 508 	of the HDLC logs
# MSE: 32.55 		at line	 2996 	of the entire log file and at line	 509 	of the HDLC logs
# MSE: 31.15 		at line	 2999 	of the entire log file and at line	 510 	of the HDLC logs
# MSE: 34.9 		at line	 3000 	of the entire log file and at line	 511 	of the HDLC logs
# MSE: 43.6 		at line	 3011 	of the entire log file and at line	 512 	of the HDLC logs
# MSE: 35.4 		at line	 3012 	of the entire log file and at line	 513 	of the HDLC logs
# MSE: 30.45 		at line	 3013 	of the entire log file and at line	 514 	of the HDLC logs
# MSE: 49.4 		at line	 3014 	of the entire log file and at line	 515 	of the HDLC logs
# MSE: 41.6 		at line	 3015 	of the entire log file and at line	 516 	of the HDLC logs
# MSE: 43.05 		at line	 3018 	of the entire log file and at line	 517 	of the HDLC logs
# MSE: 41.55 		at line	 3019 	of the entire log file and at line	 518 	of the HDLC logs
# MSE: 42.35 		at line	 3050 	of the entire log file and at line	 519 	of the HDLC logs
# MSE: 39.95 		at line	 3051 	of the entire log file and at line	 520 	of the HDLC logs
# MSE: 16.8 		at line	 3052 	of the entire log file and at line	 521 	of the HDLC logs
# MSE: 24.0 		at line	 3053 	of the entire log file and at line	 522 	of the HDLC logs
# MSE: 24.7 		at line	 3054 	of the entire log file and at line	 523 	of the HDLC logs
# MSE: 32.3 		at line	 3057 	of the entire log file and at line	 524 	of the HDLC logs
# MSE: 29.95 		at line	 3058 	of the entire log file and at line	 525 	of the HDLC logs
# MSE: 27.1 		at line	 3077 	of the entire log file and at line	 526 	of the HDLC logs
# MSE: 24.3 		at line	 3078 	of the entire log file and at line	 527 	of the HDLC logs
# MSE: 29.1 		at line	 3080 	of the entire log file and at line	 528 	of the HDLC logs
# MSE: 27.0 		at line	 3083 	of the entire log file and at line	 529 	of the HDLC logs
# MSE: 24.65 		at line	 3106 	of the entire log file and at line	 530 	of the HDLC logs
# MSE: 30.5 		at line	 3107 	of the entire log file and at line	 531 	of the HDLC logs
# MSE: 31.7 		at line	 3135 	of the entire log file and at line	 532 	of the HDLC logs
# MSE: 23.85 		at line	 3136 	of the entire log file and at line	 533 	of the HDLC logs
# MSE: 17.15 		at line	 3137 	of the entire log file and at line	 534 	of the HDLC logs
# MSE: 28.7 		at line	 3138 	of the entire log file and at line	 535 	of the HDLC logs
# MSE: 29.65 		at line	 3139 	of the entire log file and at line	 536 	of the HDLC logs
# MSE: 29.1 		at line	 3142 	of the entire log file and at line	 537 	of the HDLC logs
# MSE: 31.25 		at line	 3143 	of the entire log file and at line	 538 	of the HDLC logs
# MSE: 32.75 		at line	 3167 	of the entire log file and at line	 539 	of the HDLC logs
# MSE: 20.9 		at line	 3168 	of the entire log file and at line	 540 	of the HDLC logs
# MSE: 18.85 		at line	 3169 	of the entire log file and at line	 541 	of the HDLC logs
# MSE: 20.1 		at line	 3170 	of the entire log file and at line	 542 	of the HDLC logs
# MSE: 20.25 		at line	 3171 	of the entire log file and at line	 543 	of the HDLC logs
# MSE: 20.45 		at line	 3174 	of the entire log file and at line	 544 	of the HDLC logs
# MSE: 24.2 		at line	 3175 	of the entire log file and at line	 545 	of the HDLC logs
# MSE: 25.1 		at line	 3185 	of the entire log file and at line	 546 	of the HDLC logs
# MSE: 17.9 		at line	 3186 	of the entire log file and at line	 547 	of the HDLC logs
# MSE: 22.75 		at line	 3213 	of the entire log file and at line	 548 	of the HDLC logs
# MSE: 34.3 		at line	 3214 	of the entire log file and at line	 549 	of the HDLC logs
# MSE: 31.05 		at line	 3215 	of the entire log file and at line	 550 	of the HDLC logs
# MSE: 37.3 		at line	 3219 	of the entire log file and at line	 551 	of the HDLC logs
# MSE: 33.55 		at line	 3220 	of the entire log file and at line	 552 	of the HDLC logs
# MSE: 37.9 		at line	 3222 	of the entire log file and at line	 553 	of the HDLC logs
# MSE: 37.4 		at line	 3223 	of the entire log file and at line	 554 	of the HDLC logs
# MSE: 36.8 		at line	 3251 	of the entire log file and at line	 555 	of the HDLC logs
# MSE: 33.3 		at line	 3252 	of the entire log file and at line	 556 	of the HDLC logs
# MSE: 17.1 		at line	 3253 	of the entire log file and at line	 557 	of the HDLC logs
# MSE: 23.2 		at line	 3254 	of the entire log file and at line	 558 	of the HDLC logs
# MSE: 18.9 		at line	 3255 	of the entire log file and at line	 559 	of the HDLC logs
# MSE: 27.15 		at line	 3258 	of the entire log file and at line	 560 	of the HDLC logs
# MSE: 26.95 		at line	 3259 	of the entire log file and at line	 561 	of the HDLC logs
# MSE: 24.3 		at line	 3286 	of the entire log file and at line	 562 	of the HDLC logs
# MSE: 21.9 		at line	 3287 	of the entire log file and at line	 563 	of the HDLC logs
# MSE: 27.45 		at line	 3289 	of the entire log file and at line	 564 	of the HDLC logs
# MSE: 36.25 		at line	 3292 	of the entire log file and at line	 565 	of the HDLC logs
# MSE: 32.55 		at line	 3313 	of the entire log file and at line	 566 	of the HDLC logs
# MSE: 31.15 		at line	 3316 	of the entire log file and at line	 567 	of the HDLC logs
# MSE: 34.9 		at line	 3317 	of the entire log file and at line	 568 	of the HDLC logs
# MSE: 43.6 		at line	 3332 	of the entire log file and at line	 569 	of the HDLC logs
# MSE: 35.4 		at line	 3333 	of the entire log file and at line	 570 	of the HDLC logs
# MSE: 30.45 		at line	 3334 	of the entire log file and at line	 571 	of the HDLC logs
# MSE: 49.4 		at line	 3335 	of the entire log file and at line	 572 	of the HDLC logs
# MSE: 41.6 		at line	 3336 	of the entire log file and at line	 573 	of the HDLC logs
# MSE: 43.05 		at line	 3339 	of the entire log file and at line	 574 	of the HDLC logs
# MSE: 41.55 		at line	 3340 	of the entire log file and at line	 575 	of the HDLC logs
# MSE: 42.35 		at line	 3376 	of the entire log file and at line	 576 	of the HDLC logs
# MSE: 39.95 		at line	 3377 	of the entire log file and at line	 577 	of the HDLC logs
# MSE: 16.8 		at line	 3378 	of the entire log file and at line	 578 	of the HDLC logs
# MSE: 24.0 		at line	 3379 	of the entire log file and at line	 579 	of the HDLC logs
# MSE: 24.7 		at line	 3380 	of the entire log file and at line	 580 	of the HDLC logs
# MSE: 32.3 		at line	 3383 	of the entire log file and at line	 581 	of the HDLC logs
# MSE: 29.95 		at line	 3384 	of the entire log file and at line	 582 	of the HDLC logs
# MSE: 27.1 		at line	 3394 	of the entire log file and at line	 583 	of the HDLC logs
# MSE: 24.3 		at line	 3395 	of the entire log file and at line	 584 	of the HDLC logs
# MSE: 29.1 		at line	 3397 	of the entire log file and at line	 585 	of the HDLC logs
# MSE: 27.0 		at line	 3400 	of the entire log file and at line	 586 	of the HDLC logs
# ...
# MSE: 3.5 		at line	 11186 	of the entire log file and at line	 1832 	of the HDLC logs
# MSE: 3.55 		at line	 11187 	of the entire log file and at line	 1833 	of the HDLC logs
# MSE: 2.45 		at line	 11196 	of the entire log file and at line	 1834 	of the HDLC logs
# MSE: 4.05 		at line	 11197 	of the entire log file and at line	 1835 	of the HDLC logs
# MSE: 3.8 		at line	 11206 	of the entire log file and at line	 1836 	of the HDLC logs
# MSE: 1.4 		at line	 11207 	of the entire log file and at line	 1837 	of the HDLC logs
# MSE: 2.45 		at line	 11208 	of the entire log file and at line	 1838 	of the HDLC logs
# MSE: 4.4 		at line	 11209 	of the entire log file and at line	 1839 	of the HDLC logs
# MSE: 0.55 		at line	 11218 	of the entire log file and at line	 1840 	of the HDLC logs
# MSE: 3.05 		at line	 11219 	of the entire log file and at line	 1841 	of the HDLC logs
# MSE: 2.6 		at line	 11228 	of the entire log file and at line	 1842 	of the HDLC logs
# MSE: 1.4 		at line	 11229 	of the entire log file and at line	 1843 	of the HDLC logs
# MSE: 1.35 		at line	 11230 	of the entire log file and at line	 1844 	of the HDLC logs
# MSE: 3.35 		at line	 11231 	of the entire log file and at line	 1845 	of the HDLC logs
# MSE: 2.55 		at line	 11233 	of the entire log file and at line	 1846 	of the HDLC logs
# MSE: 1.5 		at line	 11234 	of the entire log file and at line	 1847 	of the HDLC logs
# MSE: 3.45 		at line	 11306 	of the entire log file and at line	 1848 	of the HDLC logs
# MSE: 2.05 		at line	 11307 	of the entire log file and at line	 1849 	of the HDLC logs
# MSE: 2.8 		at line	 11308 	of the entire log file and at line	 1850 	of the HDLC logs
# MSE: 0.65 		at line	 11320 	of the entire log file and at line	 1851 	of the HDLC logs
# MSE: 2.05 		at line	 11321 	of the entire log file and at line	 1852 	of the HDLC logs
# MSE: 2.45 		at line	 11325 	of the entire log file and at line	 1853 	of the HDLC logs
# MSE: 1.35 		at line	 11326 	of the entire log file and at line	 1854 	of the HDLC logs
# MSE: 2.3 		at line	 11327 	of the entire log file and at line	 1855 	of the HDLC logs
# MSE: 0.55 		at line	 11328 	of the entire log file and at line	 1856 	of the HDLC logs
# MSE: 0.65 		at line	 11349 	of the entire log file and at line	 1857 	of the HDLC logs
# MSE: 1.35 		at line	 11361 	of the entire log file and at line	 1858 	of the HDLC logs
# MSE: 2.6 		at line	 11362 	of the entire log file and at line	 1859 	of the HDLC logs
# MSE: 2.3 		at line	 11366 	of the entire log file and at line	 1860 	of the HDLC logs
# MSE: 1.2 		at line	 11367 	of the entire log file and at line	 1861 	of the HDLC logs
# MSE: 2.0 		at line	 11368 	of the entire log file and at line	 1862 	of the HDLC logs
# MSE: 1.0 		at line	 11369 	of the entire log file and at line	 1863 	of the HDLC logs
# MSE: 1.95 		at line	 11402 	of the entire log file and at line	 1864 	of the HDLC logs
# MSE: 1.9 		at line	 11413 	of the entire log file and at line	 1865 	of the HDLC logs
# MSE: 1.35 		at line	 11414 	of the entire log file and at line	 1866 	of the HDLC logs
# MSE: 3.25 		at line	 11416 	of the entire log file and at line	 1867 	of the HDLC logs
# MSE: 1.75 		at line	 11417 	of the entire log file and at line	 1868 	of the HDLC logs
# MSE: 2.25 		at line	 11418 	of the entire log file and at line	 1869 	of the HDLC logs
# MSE: 1.3 		at line	 11419 	of the entire log file and at line	 1870 	of the HDLC logs
# MSE: 1.05 		at line	 11423 	of the entire log file and at line	 1871 	of the HDLC logs
# MSE: 0.5 		at line	 11424 	of the entire log file and at line	 1872 	of the HDLC logs
# MSE: 0.9 		at line	 11426 	of the entire log file and at line	 1873 	of the HDLC logs
# MSE: 0.25 		at line	 11427 	of the entire log file and at line	 1874 	of the HDLC logs
# MSE: 0.75 		at line	 11429 	of the entire log file and at line	 1875 	of the HDLC logs
# MSE: 1.05 		at line	 11430 	of the entire log file and at line	 1876 	of the HDLC logs
# MSE: 1.0 		at line	 11441 	of the entire log file and at line	 1877 	of the HDLC logs
# MSE: 0.85 		at line	 11442 	of the entire log file and at line	 1878 	of the HDLC logs
# MSE: 0.05 		at line	 11444 	of the entire log file and at line	 1879 	of the HDLC logs
# MSE: 1.75 		at line	 11445 	of the entire log file and at line	 1880 	of the HDLC logs
# MSE: 1.3 		at line	 11456 	of the entire log file and at line	 1881 	of the HDLC logs
# MSE: 0.1 		at line	 11457 	of the entire log file and at line	 1882 	of the HDLC logs
# MSE: 0.65 		at line	 11458 	of the entire log file and at line	 1883 	of the HDLC logs
# MSE: 2.05 		at line	 11459 	of the entire log file and at line	 1884 	of the HDLC logs
# MSE: 2.45 		at line	 11463 	of the entire log file and at line	 1885 	of the HDLC logs
# MSE: 1.2 		at line	 11464 	of the entire log file and at line	 1886 	of the HDLC logs
# MSE: 1.85 		at line	 11469 	of the entire log file and at line	 1887 	of the HDLC logs
# MSE: 0.75 		at line	 11470 	of the entire log file and at line	 1888 	of the HDLC logs
# MSE: 0.85 		at line	 11474 	of the entire log file and at line	 1889 	of the HDLC logs
# MSE: 1.55 		at line	 11485 	of the entire log file and at line	 1890 	of the HDLC logs
# MSE: 2.45 		at line	 11486 	of the entire log file and at line	 1891 	of the HDLC logs
# MSE: 1.85 		at line	 11488 	of the entire log file and at line	 1892 	of the HDLC logs
# MSE: 1.35 		at line	 11489 	of the entire log file and at line	 1893 	of the HDLC logs
# MSE: 2.2 		at line	 11490 	of the entire log file and at line	 1894 	of the HDLC logs
# MSE: 1.55 		at line	 11491 	of the entire log file and at line	 1895 	of the HDLC logs
# MSE: 1.5 		at line	 11497 	of the entire log file and at line	 1896 	of the HDLC logs
# MSE: 1.45 		at line	 11505 	of the entire log file and at line	 1897 	of the HDLC logs
# MSE: 1.55 		at line	 11506 	of the entire log file and at line	 1898 	of the HDLC logs
# MSE: 3.4 		at line	 11508 	of the entire log file and at line	 1899 	of the HDLC logs
# MSE: 2.45 		at line	 11509 	of the entire log file and at line	 1900 	of the HDLC logs
# MSE: 2.1 		at line	 11510 	of the entire log file and at line	 1901 	of the HDLC logs
# MSE: 0.9 		at line	 11511 	of the entire log file and at line	 1902 	of the HDLC logs
# MSE: 1.2 		at line	 11515 	of the entire log file and at line	 1903 	of the HDLC logs
# MSE: 0.85 		at line	 11516 	of the entire log file and at line	 1904 	of the HDLC logs
# MSE: 1.85 		at line	 11518 	of the entire log file and at line	 1905 	of the HDLC logs
# MSE: 0.8 		at line	 11521 	of the entire log file and at line	 1906 	of the HDLC logs
# MSE: 0.25 		at line	 11542 	of the entire log file and at line	 1907 	of the HDLC logs
# MSE: 0.75 		at line	 11545 	of the entire log file and at line	 1908 	of the HDLC logs
# MSE: 1.05 		at line	 11546 	of the entire log file and at line	 1909 	of the HDLC logs
# MSE: 1.0 		at line	 11557 	of the entire log file and at line	 1910 	of the HDLC logs
# MSE: 0.85 		at line	 11558 	of the entire log file and at line	 1911 	of the HDLC logs
# MSE: 0.05 		at line	 11560 	of the entire log file and at line	 1912 	of the HDLC logs
# MSE: 1.75 		at line	 11561 	of the entire log file and at line	 1913 	of the HDLC logs
# MSE: 1.3 		at line	 11575 	of the entire log file and at line	 1914 	of the HDLC logs
# MSE: 0.1 		at line	 11576 	of the entire log file and at line	 1915 	of the HDLC logs
# MSE: 0.65 		at line	 11577 	of the entire log file and at line	 1916 	of the HDLC logs
# MSE: 2.05 		at line	 11578 	of the entire log file and at line	 1917 	of the HDLC logs
# MSE: 2.45 		at line	 11583 	of the entire log file and at line	 1918 	of the HDLC logs
# MSE: 1.35 		at line	 11584 	of the entire log file and at line	 1919 	of the HDLC logs
# MSE: 2.3 		at line	 11590 	of the entire log file and at line	 1920 	of the HDLC logs
# MSE: 0.55 		at line	 11591 	of the entire log file and at line	 1921 	of the HDLC logs
# MSE: 0.65 		at line	 11595 	of the entire log file and at line	 1922 	of the HDLC logs
# MSE: 1.35 		at line	 11607 	of the entire log file and at line	 1923 	of the HDLC logs
# MSE: 2.6 		at line	 11608 	of the entire log file and at line	 1924 	of the HDLC logs
# MSE: 2.3 		at line	 11611 	of the entire log file and at line	 1925 	of the HDLC logs
# MSE: 1.2 		at line	 11612 	of the entire log file and at line	 1926 	of the HDLC logs
# MSE: 2.0 		at line	 11613 	of the entire log file and at line	 1927 	of the HDLC logs
# MSE: 1.0 		at line	 11620 	of the entire log file and at line	 1928 	of the HDLC logs
# MSE: 1.95 		at line	 11624 	of the entire log file and at line	 1929 	of the HDLC logs
# MSE: 1.9 		at line	 11632 	of the entire log file and at line	 1930 	of the HDLC logs
# MSE: 1.35 		at line	 11633 	of the entire log file and at line	 1931 	of the HDLC logs
# MSE: 3.25 		at line	 11635 	of the entire log file and at line	 1932 	of the HDLC logs
# MSE: 1.75 		at line	 11636 	of the entire log file and at line	 1933 	of the HDLC logs
# MSE: 2.25 		at line	 11637 	of the entire log file and at line	 1934 	of the HDLC logs
# MSE: 1.3 		at line	 11638 	of the entire log file and at line	 1935 	of the HDLC logs
# MSE: 1.05 		at line	 11642 	of the entire log file and at line	 1936 	of the HDLC logs
# MSE: 0.5 		at line	 11643 	of the entire log file and at line	 1937 	of the HDLC logs
# MSE: 0.9 		at line	 11645 	of the entire log file and at line	 1938 	of the HDLC logs
# MSE: 0.25 		at line	 11646 	of the entire log file and at line	 1939 	of the HDLC logs
# MSE: 0.75 		at line	 11648 	of the entire log file and at line	 1940 	of the HDLC logs
# MSE: 1.05 		at line	 11649 	of the entire log file and at line	 1941 	of the HDLC logs
# MSE: 1.0 		at line	 11660 	of the entire log file and at line	 1942 	of the HDLC logs
# MSE: 0.85 		at line	 11661 	of the entire log file and at line	 1943 	of the HDLC logs
# MSE: 0.05 		at line	 11663 	of the entire log file and at line	 1944 	of the HDLC logs
# MSE: 1.75 		at line	 11664 	of the entire log file and at line	 1945 	of the HDLC logs
# MSE: 1.3 		at line	 11675 	of the entire log file and at line	 1946 	of the HDLC logs
# MSE: 0.1 		at line	 11676 	of the entire log file and at line	 1947 	of the HDLC logs
# MSE: 0.65 		at line	 11677 	of the entire log file and at line	 1948 	of the HDLC logs
# MSE: 2.05 		at line	 11678 	of the entire log file and at line	 1949 	of the HDLC logs
# MSE: 2.45 		at line	 11682 	of the entire log file and at line	 1950 	of the HDLC logs
# MSE: 1.2 		at line	 11683 	of the entire log file and at line	 1951 	of the HDLC logs
# MSE: 1.85 		at line	 11684 	of the entire log file and at line	 1952 	of the HDLC logs
# MSE: 0.75 		at line	 11685 	of the entire log file and at line	 1953 	of the HDLC logs
# MSE: 0.85 		at line	 11693 	of the entire log file and at line	 1954 	of the HDLC logs
# MSE: 1.55 		at line	 11704 	of the entire log file and at line	 1955 	of the HDLC logs
# MSE: 2.45 		at line	 11705 	of the entire log file and at line	 1956 	of the HDLC logs
# MSE: 1.85 		at line	 11707 	of the entire log file and at line	 1957 	of the HDLC logs
# MSE: 1.35 		at line	 11708 	of the entire log file and at line	 1958 	of the HDLC logs
# MSE: 2.2 		at line	 11709 	of the entire log file and at line	 1959 	of the HDLC logs
# MSE: 1.55 		at line	 11710 	of the entire log file and at line	 1960 	of the HDLC logs
# MSE: 1.5 		at line	 11716 	of the entire log file and at line	 1961 	of the HDLC logs
# MSE: 1.45 		at line	 11724 	of the entire log file and at line	 1962 	of the HDLC logs
# MSE: 1.55 		at line	 11725 	of the entire log file and at line	 1963 	of the HDLC logs
# MSE: 3.4 		at line	 11727 	of the entire log file and at line	 1964 	of the HDLC logs
# MSE: 2.45 		at line	 11728 	of the entire log file and at line	 1965 	of the HDLC logs
# MSE: 2.1 		at line	 11729 	of the entire log file and at line	 1966 	of the HDLC logs
# MSE: 0.9 		at line	 11730 	of the entire log file and at line	 1967 	of the HDLC logs
# MSE: 1.2 		at line	 11734 	of the entire log file and at line	 1968 	of the HDLC logs
# MSE: 0.85 		at line	 11735 	of the entire log file and at line	 1969 	of the HDLC logs
# MSE: 1.85 		at line	 11737 	of the entire log file and at line	 1970 	of the HDLC logs
# MSE: 0.8 		at line	 11740 	of the entire log file and at line	 1971 	of the HDLC logs
# MSE: 0.25 		at line	 11761 	of the entire log file and at line	 1972 	of the HDLC logs
# MSE: 0.75 		at line	 11764 	of the entire log file and at line	 1973 	of the HDLC logs
# MSE: 1.05 		at line	 11765 	of the entire log file and at line	 1974 	of the HDLC logs
# MSE: 1.0 		at line	 11776 	of the entire log file and at line	 1975 	of the HDLC logs
# MSE: 0.85 		at line	 11777 	of the entire log file and at line	 1976 	of the HDLC logs
# MSE: 0.05 		at line	 11779 	of the entire log file and at line	 1977 	of the HDLC logs
# MSE: 1.75 		at line	 11780 	of the entire log file and at line	 1978 	of the HDLC logs
# MSE: 1.3 		at line	 11794 	of the entire log file and at line	 1979 	of the HDLC logs
# MSE: 0.1 		at line	 11795 	of the entire log file and at line	 1980 	of the HDLC logs
# MSE: 0.65 		at line	 11796 	of the entire log file and at line	 1981 	of the HDLC logs
# MSE: 2.05 		at line	 11797 	of the entire log file and at line	 1982 	of the HDLC logs
# MSE: 2.45 		at line	 11802 	of the entire log file and at line	 1983 	of the HDLC logs
# MSE: 1.2 		at line	 11803 	of the entire log file and at line	 1984 	of the HDLC logs
# MSE: 2.05 		at line	 11804 	of the entire log file and at line	 1985 	of the HDLC logs
# MSE: 0.75 		at line	 11805 	of the entire log file and at line	 1986 	of the HDLC logs
# MSE: 0.85 		at line	 11814 	of the entire log file and at line	 1987 	of the HDLC logs
# MSE: 1.55 		at line	 11826 	of the entire log file and at line	 1988 	of the HDLC logs
# MSE: 2.7 		at line	 11827 	of the entire log file and at line	 1989 	of the HDLC logs
# MSE: 2.7 		at line	 11830 	of the entire log file and at line	 1990 	of the HDLC logs
# MSE: 1.55 		at line	 11831 	of the entire log file and at line	 1991 	of the HDLC logs
# MSE: 2.2 		at line	 11832 	of the entire log file and at line	 1992 	of the HDLC logs
# MSE: 1.55 		at line	 11833 	of the entire log file and at line	 1993 	of the HDLC logs
# MSE: 1.7 		at line	 11844 	of the entire log file and at line	 1994 	of the HDLC logs
# MSE: 2.9 		at line	 11852 	of the entire log file and at line	 1995 	of the HDLC logs
# MSE: 8.2 		at line	 11853 	of the entire log file and at line	 1996 	of the HDLC logs
# MSE: 10.15 		at line	 11855 	of the entire log file and at line	 1997 	of the HDLC logs
# MSE: 1.9 		at line	 11856 	of the entire log file and at line	 1998 	of the HDLC logs
# MSE: 2.3 		at line	 11857 	of the entire log file and at line	 1999 	of the HDLC logs
# MSE: 1.25 		at line	 11858 	of the entire log file and at line	 2000 	of the HDLC logs
# MSE: 1.85 		at line	 11862 	of the entire log file and at line	 2001 	of the HDLC logs
# MSE: 1.8 		at line	 11863 	of the entire log file and at line	 2002 	of the HDLC logs
# MSE: 1.3 		at line	 11865 	of the entire log file and at line	 2003 	of the HDLC logs
# MSE: 0.45 		at line	 11868 	of the entire log file and at line	 2004 	of the HDLC logs
# MSE: 0.75 		at line	 11891 	of the entire log file and at line	 2005 	of the HDLC logs
# MSE: 1.05 		at line	 11892 	of the entire log file and at line	 2006 	of the HDLC logs
# MSE: 1.0 		at line	 11903 	of the entire log file and at line	 2007 	of the HDLC logs
# MSE: 0.85 		at line	 11904 	of the entire log file and at line	 2008 	of the HDLC logs
# MSE: 1.3 		at line	 11906 	of the entire log file and at line	 2009 	of the HDLC logs
# MSE: 3.05 		at line	 11907 	of the entire log file and at line	 2010 	of the HDLC logs
# MSE: 2.6 		at line	 11921 	of the entire log file and at line	 2011 	of the HDLC logs
# MSE: 1.4 		at line	 11922 	of the entire log file and at line	 2012 	of the HDLC logs
# MSE: 1.35 		at line	 11923 	of the entire log file and at line	 2013 	of the HDLC logs
# MSE: 3.35 		at line	 11924 	of the entire log file and at line	 2014 	of the HDLC logs
# MSE: 2.55 		at line	 11929 	of the entire log file and at line	 2015 	of the HDLC logs
